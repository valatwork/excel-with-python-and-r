# %% [markdown]
# # 21

# %%
import pandas as pd

# %% [markdown]
# 1 Create a data frame from the file nyc-parking-violations-2020.csv. We are only interested in a handful of the columns:
# - Date First Observed
# - Plate ID
# - Registration State
# - Issue Date (a string in MM/DD/YYYY format, always followed by 12:00:00
# - Vehicle Make
# - Street Name
# - Vehicle Color

# %%
nyc_pv = pd.read_csv('./data/nyc-parking-violations-2020.csv',
                    usecols=['Date First Observed','Plate ID', 'Registration State', 'Issue Date', 'Vehicle Make', 'Street Name', 'Vehicle Color'])

# %% [markdown]
# Set the data frame’s index to the Issue Date column.

# %%
df = nyc_pv.set_index('Issue Date')

# %% [markdown]
# Determine what three makes were most frequently ticketed on January 2, 2020

# %%
df.loc['01/02/2020 12:00:00 AM', 'Vehicle Make'].value_counts().head(3)
# Out:
# Vehicle Make
# TOYOT    3829
# HONDA    3593
# FORD     3164
# Name: count, dtype: int64

# %% [markdown]
# Determine the five streets on which cars got the most tickets on June 1, 2020.

# %%
df.loc['06/01/2020 12:00:00 AM', 'Street Name'].value_counts().head(5)
# Out:
# Street Name
# WB CONDUIT BLVD @ LI    1068
# SB WEST ST @ LEROY S     335
# EB HORACE HARDING EX     273
# EB QUEENS BLVD @ 82N     245
# WB ATLANTIC AVE @ CL     229
# Name: count, dtype: int64

# %% [markdown]
# Set the index to `Vehicle Color`.

# %%
df = df.reset_index().set_index('Vehicle Color')

# %% [markdown]
# Determine the most common make of vehicles that were either red or blue

# %%
(df.loc[['BLUE', 'RED'], 'Vehicle Make'].value_counts().head(1))
# Out:
# Vehicle Make
# HONDA    39353
# Name: count, dtype: int64

# %% [markdown]
# What three car makes were most often ticketed from January 2 through January 10?

# %%
df = df.reset_index()   # undo the setting of the index from the previous cell

# let's do it in chained format:

(
    df
    .set_index('Issue Date')
    .sort_index()
    .loc['01/02/2020 12:00:00 AM':'01/10/2020 23:59:59 PM',
         'Vehicle Make']
    .value_counts()
    .head(3)
)
# Out:
# Vehicle Make
# FORD     38958
# TOYOT    37096
# HONDA    35962
# Name: count, dtype: int64

# %% [markdown]
# How many tickets did the second-most-ticketed car get in 2020?

# %%
df = df.reset_index()
df['Plate ID'].value_counts().head(2)
# Out:
# Plate ID
# BLANKPLATE    8882
# 2704819       1535
# Name: count, dtype: int64

# %% [markdown]
# What state was that car from?

# %%
df = df.set_index('Plate ID')
df.loc['2704819', 'Registration State']
# Out:
# Plate ID
# 2704819    IN
# 2704819    IN
# 2704819    IN
# 2704819    IN
# 2704819    IN
#            ..
# 2704819    IN
# 2704819    IN
# 2704819    IN
# 2704819    IN
# 2704819    IN
# Name: Registration State, Length: 1535, dtype: object

# %% [markdown]
# Was it always ticketed in the same location?

# %%
df.loc['2704819', 'Street Name'].value_counts()
# Out:
# Street Name
# 8th Ave                 395
# Penn Plz                230
# 7th Ave                  92
# 9th Ave                  63
# Broadway                 57
#                        ...
# WEST 36 STREET            1
# N/S W 25 ST               1
# AVENUE OF THE AMERIC      1
# WEST 41 ST                1
# N/S W 31 ST               1
# Name: count, Length: 113, dtype: int64

# %% [markdown]
# # 22

# %% [markdown]
# Read in the scores file, only keeping the `Year`, `State.Code`, `Total.Math`, `Total.Test-takers`, and `Total.Verbal` columns.

# %%
sat_scores = pd.read_csv('./data/sat-scores.csv',
                         usecols= ['Year', 'State.Code', 'Total.Math', 'Total.Test-takers', 'Total.Verbal'])

# %% [markdown]
# Create a multi-index based on the year and the two-letter state code.

# %%
df = sat_scores.set_index(['Year', 'State.Code'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 577 entries, (np.int64(2005), 'AL') to (np.int64(2015), 'WY')
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Total.Math         577 non-null    int64
#  1   Total.Test-takers  577 non-null    int64
#  2   Total.Verbal       577 non-null    int64
# dtypes: int64(3)
# memory usage: 17.6+ KB

# %% [markdown]
# Determine how many people took the SAT in 2005.

# %%
df.loc[2005, 'Total.Test-takers'].sum()
# Out:
# np.int64(1344824)

# %% [markdown]
# Determine the average SAT math score in 2010 from New York (NY), New Jersey (NJ), Massachusetts (MA), and Illinois (IL).

# %%
df.loc[(2010, ['NY', 'NJ', 'MA', 'IL']), 'Total.Math'].mean()
# Out:
# np.float64(535.25)

# %% [markdown]
# Determine the average SAT verbal score in 2012–2015 from Arizona (AZ), California (CA), and Texas (TX).

# %%
df.loc[([2012,2013,2014,2015], ['AZ', 'CA', 'TX']), 'Total.Verbal'].mean()
# Out:
# np.float64(497.3333333333333)

# %% [markdown]
# # 23

# %% [markdown]
# Read the data file (`olympic_athlete_events.csv`) into a data frame, keep these columns: `Age`, `Height`, `Team`, `Year`, `Season`, `City`, `Sport`,
# `Event`, and `Medal`.
#
# The multi-index should be based on `Year`, `Season`, `Sport`, and `Event`.

# %%
olympic_athlete_events = pd.read_csv('./data/olympic_athlete_events.csv',
                                     usecols=['Age', 'Height', 'Team', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
                                     index_col= ['Year', 'Season', 'Sport', 'Event'])

# %%
olympic_athlete_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 271116 entries, (np.int64(1992), 'Summer', 'Basketball', "Basketball Men's Basketball") to (np.int64(2002), 'Winter', 'Bobsleigh', "Bobsleigh Men's Four")
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Age     261642 non-null  float64
#  1   Height  210945 non-null  float64
#  2   Team    271116 non-null  object
#  3   City    271116 non-null  object
#  4   Medal   39783 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 11.7+ MB

# %%
df = olympic_athlete_events.sort_index()
df.head()
# Out:
#                                                      Age  Height  \
# Year Season Sport     Event
# 1896 Summer Athletics Athletics Men's 1,500 metres  24.0     NaN
#                       Athletics Men's 1,500 metres   NaN     NaN
#                       Athletics Men's 1,500 metres  22.0     NaN
#                       Athletics Men's 1,500 metres  23.0   154.0
#                       Athletics Men's 1,500 metres  21.0     NaN
#
#                                                              Team    City  \
# Year Season Sport     Event
# 1896 Summer Athletics Athletics Men's 1,500 metres  United States  Athina
#                       Athletics Men's 1,500 metres         Greece  Athina
#                       Athletics Men's 1,500 metres      Australia  Athina
#                       Athletics Men's 1,500 metres        Germany  Athina
#                       Athletics Men's 1,500 metres         Greece  Athina
#
#                                                      Medal
# ...

# %% [markdown]
# What is the average age of the competing athletes in summer games held between 1936 and 2000?

# %%
df.loc[(slice(1936,2000), 'Summer'), 'Age'].mean()
# Out:
# np.float64(25.026883940421765)

# %% [markdown]
# Which team won the most medals in all archery events?

# %%
df.dropna(subset='Medal').loc[(slice(None), 'Summer', 'Archery'), 'Team'].value_counts()
# Out:
# Team
# South Korea           69
# Belgium               52
# France                48
# United States         41
# China                 19
# Italy                 15
# Great Britain         13
# Chinese Taipei         9
# Netherlands            9
# Ukraine                8
# Cincinnati Archers     8
# Japan                  7
# Germany                7
# Soviet Union           7
# Finland                6
# Australia              5
# Boston Archers         4
# Unified Team           4
# Potomac Archers        4
# Russia                 4
# Poland                 4
# Spain                  3
# Indonesia              3
# Sweden                 2
# Mexico                 2
# Name: count, dtype: int64

# %% [markdown]
# Starting in 1980, what is the average height of the “Table Tennis Women’s Team” event?

# %%
df.loc[(slice(1980, None), 'Summer', slice(None), 'Table Tennis Women\'s Team'), 'Height'].mean()
# Out:
# np.float64(165.04827586206898)

# %% [markdown]
# Starting in 1980, what is the average height of both “Table Tennis Women’s Team” and “Table Tennis Men’s Team”?

# %%
df.loc[(slice(1980, None), 'Summer', slice(None), ['Table Tennis Men\'s Team', 'Table Tennis Women\'s Team']), 'Height'].mean()
# Out:
# np.float64(171.26643598615917)

# %% [markdown]
# Using `xs`, we can shorten that query to:

# %%
df.xs('Table Tennis Women\'s Team', level='Event')['Height'].mean()
# if we didn't know the season, we could use:
# df.xs(('Summer', 'Table Tennis Women\'s Team'), level=['Season', 'Event'])['Height'].mean()
# Out:
# np.float64(165.04827586206898)

# %% [markdown]
# A more general way to retrieve from a multi-index is `IndexSlice`.

# %%
from pandas import IndexSlice as idx

# %%
df.loc[idx[1980:2016, :, 'Swimming':'Table tennis'], :]
# Out:
#                                                                  Age  Height  \
# Year Season Sport        Event
# 1980 Summer Swimming     Swimming Men's 1,500 metres Freestyle  19.0   185.0
#                          Swimming Men's 1,500 metres Freestyle  18.0   181.0
#                          Swimming Men's 1,500 metres Freestyle  19.0   178.0
#                          Swimming Men's 1,500 metres Freestyle  21.0   184.0
#                          Swimming Men's 1,500 metres Freestyle  16.0   174.0
# ...                                                              ...     ...
# 2016 Summer Table Tennis Table Tennis Women's Team              26.0   166.0
#                          Table Tennis Women's Team              20.0   166.0
#                          Table Tennis Women's Team              25.0   162.0
#                          Table Tennis Women's Team              28.0   165.0
#                          Table Tennis Women's Team              22.0   168.0
#
# ...

# %% [markdown]
# How tall was the tallest-ever tennis player in Olympic games from 1980 until 2016?
#
# Since Tennis is a summer sport, let's remove `Season` from the index.

# %%
df = df.reset_index('Season')

# %%
df.loc[(slice(1980,2020), 'Tennis'), 'Height'].max()
# Out:
# np.float64(208.0)

# %% [markdown]
# In which city were the most gold medals awarded from 1980 onward?

# %%
df.loc[1980:].loc[lambda df_: df_['Medal'] == 'Gold', 'City'].value_counts()
# Out:
# City
# Beijing           671
# Rio de Janeiro    665
# Athina            664
# Sydney            663
# London            632
# Atlanta           608
# Barcelona         559
# Seoul             520
# Los Angeles       497
# Moskva            457
# Sochi             202
# Torino            176
# Vancouver         174
# Salt Lake City    162
# Nagano            145
# Lillehammer       110
# Albertville       104
# Calgary            87
# Sarajevo           74
# Lake Placid        72
# Name: count, dtype: int64

# %% [markdown]
# How many gold medals were received by the United States since 1980?

# %%
df.loc[1980:].loc[lambda df_: (df_['Team'] == 'United States') & (df_['Medal'] == 'Gold'), 'City'].count()
# Out:
# np.int64(1257)

# %% [markdown]
# # 24

# %% [markdown]
# Read in our Olympic data again.
# - Only use these columns: `Age`, `Height`, `Team`, `Year`, `Season`, `Sport`, `Medal`.
# - Only include games from 1980 to the present.
# - Only include data from these countries: Great Britain, France, United States, Switzerland, China, and India

# %%
df = olympic_athlete_events.reset_index()[['Age', 'Height', 'Team', 'Year', 'Season', 'Sport', 'Medal']]
df = df.loc[df['Team'].isin(['Great Britain', 'France', 'United States', 'Switzerland', 'China', 'India'])]
df = df.loc[df['Year'] >= 1980]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27893 entries, 0 to 271037
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     27879 non-null  float64
#  1   Height  27350 non-null  float64
#  2   Team    27893 non-null  object
#  3   Year    27893 non-null  int64
#  4   Season  27893 non-null  object
#  5   Sport   27893 non-null  object
#  6   Medal   5256 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.7+ MB

# %% [markdown]
# What was the average age of Olympic athletes? In which country do players appear to consistently be the youngest?

# %%
df.pivot_table(index='Year', columns='Team', values='Age')
# Out:
# Team      China     France  Great Britain      India  Switzerland  \
# Year
# 1980  21.868421  23.524590      22.882507  25.506667    24.557823
# 1984  22.076336  24.369830      24.445423  24.905660    23.589744
# 1988  22.358447  24.520076      25.439560  24.000000    26.218868
# 1992  21.955752  25.140187      25.584055  24.184615    25.413194
# 1994  20.627907  24.601307      25.282051        NaN    25.500000
# 1996  22.021531  25.296629      26.746032  24.629630    27.122093
# 1998  21.784091  25.462069      27.243902  16.000000    25.641509
# 2000  22.515306  25.982833      26.406948  25.400000    27.376812
# 2002  23.127451  25.737805      26.833333  20.000000    26.238710
# 2004  23.006122  26.139073      26.303977  24.728395    27.343284
# 2006  23.457143  26.303226      26.851852  25.200000    26.284848
# 2008  23.903955  26.285714      25.200969  25.402985    27.312500
# 2010  23.239669  25.911458      26.147059  25.666667    26.548387
# ...

# %% [markdown]
# How tall were the tallest athletes in each sport in each year?

# %%
df.pivot_table(
    index='Sport',
    columns='Year',
    values='Height',
    aggfunc='max'
)
# Out:
# Year                        1980   1984   1988   1992   1994   1996   1998  \
# Sport
# Alpine Skiing              184.0  184.0  185.0  185.0  188.0    NaN  188.0
# Archery                    185.0  188.0  188.0  191.0    NaN  191.0    NaN
# Athletics                  197.0  203.0  203.0  200.0    NaN  198.0    NaN
# Badminton                    NaN    NaN    NaN  186.0    NaN  189.0    NaN
# Baseball                     NaN    NaN    NaN  198.0    NaN  195.0    NaN
# Basketball                 196.0  216.0  216.0  216.0    NaN  216.0    NaN
# Beach Volleyball             NaN    NaN    NaN    NaN    NaN  193.0    NaN
# Biathlon                   190.0  190.0  188.0  192.0  192.0    NaN  192.0
# Bobsleigh                    NaN  184.0    NaN    NaN    NaN    NaN  198.0
# Boxing                     190.0  195.0  196.0  193.0    NaN  191.0    NaN
# Canoeing                   203.0  203.0  203.0  203.0    NaN  205.0    NaN
# ...

# %% [markdown]
# How many medals did each country earn each year?

# %%
pd.pivot_table(df.dropna(subset='Medal'),
               index='Year',
               columns='Team',
               values='Medal',
               aggfunc='size'
               )
# Out:
# Team  China  France  Great Britain  India  Switzerland  United States
# Year
# 1980    NaN    30.0           48.0   16.0          5.0           30.0
# 1984   74.0    70.0           71.0    NaN         17.0          359.0
# 1988   50.0    31.0           54.0    NaN         24.0          212.0
# 1992   73.0    65.0           50.0    NaN          2.0          236.0
# 1994    3.0    11.0            3.0    NaN          8.0           19.0
# 1996   94.0    49.0           26.0    1.0         11.0          255.0
# 1998   14.0    13.0            4.0    NaN         10.0           30.0
# 2000   65.0    64.0           52.0    1.0         14.0          240.0
# 2002   14.0    13.0            6.0    NaN         20.0           70.0
# 2004   82.0    53.0           55.0    1.0          5.0          259.0
# 2006    9.0    15.0            1.0    NaN         15.0           48.0
# 2008  170.0    77.0           81.0    3.0         11.0          309.0
# ...

# %% [markdown]
# Create a pivot table that shows the number of medals each team won per year, with the index including the year and the season in which the games took place.

# %%
df.pivot_table(
    index=['Year', 'Season'],
    columns='Team',
    values='Medal',
    aggfunc='size',
)
# Out:
# Team         China  France  Great Britain  India  Switzerland  United States
# Year Season
# 1980 Summer    NaN   200.0          328.0   78.0         86.0            NaN
#      Winter   38.0    44.0           56.0    NaN         61.0          131.0
# 1984 Summer  323.0   354.0          509.0   53.0        245.0          693.0
#      Winter   70.0    57.0           60.0    NaN         67.0          128.0
# 1988 Summer  423.0   413.0          468.0   55.0        151.0          715.0
#      Winter   15.0   111.0           79.0    3.0        114.0          171.0
# 1992 Summer  378.0   476.0          500.0   61.0        171.0          728.0
#      Winter   74.0   166.0           78.0    4.0        117.0          208.0
# 1994 Winter   43.0   153.0           39.0    NaN         94.0          215.0
# 1996 Summer  418.0   445.0          379.0   54.0        172.0          827.0
# 1998 Winter   88.0   145.0           41.0    1.0        106.0          260.0
# ...

# %% [markdown]
# Create a pivot table that shows both the average age and the average height per year per team.

# %%
pd.pivot_table(df,
               index='Year',
               columns='Team',
               values=['Age', 'Height'],
               aggfunc='max')
# Out:
#        Age                                                      Height         \
# Team China France Great Britain India Switzerland United States  China France
# Year
# 1980  32.0   34.0          37.0  56.0        47.0          32.0  170.0  203.0
# 1984  30.0   50.0          47.0  45.0        52.0          49.0  216.0  214.0
# 1988  34.0   43.0          55.0  36.0        47.0          52.0  210.0  203.0
# 1992  35.0   47.0          48.0  38.0        53.0          54.0  215.0  203.0
# 1994  29.0   33.0          36.0   NaN        35.0          36.0  181.0  195.0
# 1996  39.0   53.0          48.0  46.0        49.0          50.0  215.0  201.0
# 1998  29.0   34.0          36.0  16.0        37.0          40.0  185.0  198.0
# 2000  39.0   46.0          52.0  38.0        53.0          46.0  226.0  218.0
# 2002  30.0   38.0          40.0  20.0        36.0          48.0  188.0  190.0
# 2004  43.0   50.0          48.0  43.0        55.0          52.0  226.0  202.0
# ...

# %% [markdown]
# Create a pivot table that shows the average age and the average height per year, per team, broken up by year and season.

# %%
pd.pivot_table(df,
               index=['Year', 'Season'],
               columns='Team',
               values=['Age', 'Height'],
               aggfunc='max')
# Out:
#               Age                                                      Height  \
# Team        China France Great Britain India Switzerland United States  China
# Year Season
# 1980 Summer   NaN   34.0          37.0  56.0        47.0           NaN    NaN
#      Winter  32.0   29.0          36.0   NaN        33.0          32.0  170.0
# 1984 Summer  30.0   50.0          47.0  45.0        52.0          49.0  216.0
#      Winter  28.0   36.0          34.0   NaN        30.0          34.0  176.0
# 1988 Summer  34.0   43.0          55.0  36.0        47.0          52.0  210.0
#      Winter  24.0   39.0          29.0  24.0        34.0          39.0  181.0
# 1992 Summer  35.0   47.0          48.0  38.0        53.0          54.0  215.0
#      Winter  29.0   32.0          30.0  21.0        32.0          36.0  181.0
# 1994 Winter  29.0   33.0          36.0   NaN        35.0          36.0  181.0
# 1996 Summer  39.0   53.0          48.0  46.0        49.0          50.0  215.0
# ...
